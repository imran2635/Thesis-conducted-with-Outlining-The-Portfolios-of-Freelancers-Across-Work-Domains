# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as split
import seaborn

# %%
df = pd.read_csv("/content/Data_Agencies.xlsx - Recovered_Sheet1 (1).csv")

# %%
df
# Out:
#                            Name          Domain         Country  HourlyIncome  \
# 0                  Rienie Du P.      Freelancer    South Africa          50.0
# 1                     Hassan M.  Administration        Pakistan           5.5
# 2     Venkata Samba Siva Rao A.      Freelancer           India          30.0
# 3                     Rameez S.      Accountant        Pakistan          20.0
# 4                      Azmat Q.      Data Entry        Pakistan           6.0
# ...                         ...             ...             ...           ...
# 2496            Oluwatunmise A.     Copy Writer         Nigeria          15.0
# 2497                     Dil A.     Copy Writer      Bangladesh          20.0
# 2498                     Cem R.  Content Writer  United Kingdom          90.0
# 2499            Sharmishtha  D.  Content Writer           India          25.0
# 2500                Narender K.  Content Writer           India          10.0
#
#       TotalIncome                                                Bio  \
# 0             0.0  Im a spontaneous hard working go getter that w...
# 1           200.0  Three years of experience in recruitment sourc...
# 2            50.0  Graphic designing skills:\n\nDesign:\n--------...
# 3             0.0  I perform my duties as an experienced bookkeep...
# 4             0.0  ✨✨✨𝐀𝐦𝐚𝐳𝐨𝐧, 𝐞𝐁𝐚𝐲, 𝐀𝐦𝐚𝐳𝐨𝐧 𝐕𝐞𝐧𝐝𝐨𝐫, 𝐖𝐚𝐥𝐦𝐚𝐫𝐭, 𝐄𝐭𝐬𝐲,...
# ...           ...                                                ...
# 2496         70.0  I believe that storytelling is the most powerf...
# 2497          2.0  I am an expert and experienced in Article Writ...
# 2498          NaN  Born & raised in London, UK, so I'm a natural ...
# 2499          NaN  I am an experienced E-books, web content and a...
# 2500         30.0  This was the thing I was always hoping to add ...
#
#                                AgencyName  Rating      ClassLabel  \
# 0                      Futuristic Changes    0.00  Below Average
# 1                                Rajawork    1.00       Excellent
# 2     Charam Global Solutions PVT LTD OPC    1.00       Excellent
# 3     Extreme Business Solutions Pvt Ltd.    0.00  Below Average
# 4                 Multan Seller Solutions    0.97       Excellent
# ...                                   ...     ...             ...
# 2496            Exodus Digital Enterprise    0.00  Below Average
# 2497                       Metadiv Studio    0.00  Below Average
# 2498                      SpectrumKod Ltd    0.00  Below Average
# 2499                       Nayra Infotech    0.00  Below Average
# 2500                            ROI Minds    0.00  Below Average
#
#               up-skill-badge  ...        up-skill-badge 9  \
# 0                        NaN  ...                     NaN
# 1               Construction  ...        Resume Screening
# 2                     Course  ...                     NaN
# 3           Accounts Payable  ...     Accounting Software
# 4                        NaN  ...                     NaN
# ...                      ...  ...                     ...
# 2496        Creative Writing  ...            Blog Content
# 2497  Editing & Proofreading  ...                     NaN
# 2498           Business Plan  ...  Editing & Proofreading
# 2499  Indian English Dialect  ...                 Article
# 2500            Blog Content  ...              Researcher
#
#          up-skill-badge 10   up-skill-badge 11  up-skill-badge 12  \
# 0                      NaN                 NaN                NaN
# 1     Interpersonal Skills  Candidate Sourcing                NaN
# 2                      NaN                 NaN                NaN
# 3          Numeric Fluency          Data Entry  Accounting Basics
# 4                      NaN                 NaN                NaN
# ...                    ...                 ...                ...
# 2496                 eBook                 NaN                NaN
# 2497                   NaN                 NaN                NaN
# 2498                   NaN                 NaN                NaN
# 2499             Biography                 NaN                NaN
# 2500                   SEO                 NaN                NaN
#
#      up-skill-badge 13  up-skill-badge 14 up-skill-badge 15 up-skill-badge 16  \
# 0                  NaN                NaN               NaN               NaN
# 1                  NaN                NaN               NaN               NaN
# 2                  NaN                NaN               NaN               NaN
# 3           Quickbooks  Oracle Accounting   Microsoft Excel  Customer Service
# 4                  NaN                NaN               NaN               NaN
# ...                ...                ...               ...               ...
# 2496               NaN                NaN               NaN               NaN
# 2497               NaN                NaN               NaN               NaN
# 2498               NaN                NaN               NaN               NaN
# 2499               NaN                NaN               NaN               NaN
# 2500               NaN                NaN               NaN               NaN
#
#      RequiredSkills TotalSkills
# 0                16           0
# 1                 5          11
# 2                 9           7
# 3                 0          16
# 4                16           0
# ...             ...         ...
# 2496              6          10
# 2497              8           8
# 2498              7           9
# 2499              6          10
# 2500              6          10
#
# [2501 rows x 27 columns]

# %% [markdown]
# Visualizing the data

# %%
#Visualizing the data
import seaborn as sns
import matplotlib.pyplot as plt
df['ClassLabel'].value_counts().plot(kind='bar')

# %%
x=df['ClassLabel'].value_counts()
colors = ['#96D38C', '#D0F9B1']
plt.pie(x, labels=x.index, colors=colors,startangle=90,autopct='%.1f%%')

plt.title('labels in %')
plt.show()

# %%
#Plotting the data distribution
df.hist(bins = 50,figsize = (50,50))
plt.show()

# %%
df.shape
# Out:
# (2501, 27)

# %%
#Listing the features of the dataset
df.columns
# Out:
# Index(['Name', 'Domain', 'Country', 'HourlyIncome', 'TotalIncome', 'Bio',
#        ' AgencyName', 'Rating', 'ClassLabel', 'up-skill-badge',
#        'up-skill-badge 2', 'up-skill-badge 3', 'up-skill-badge 4',
#        'up-skill-badge 5', 'up-skill-badge 6', 'up-skill-badge 7',
#        'up-skill-badge 8', 'up-skill-badge 9', 'up-skill-badge 10',
#        'up-skill-badge 11', 'up-skill-badge 12', 'up-skill-badge 13',
#        'up-skill-badge 14', 'up-skill-badge 15', 'up-skill-badge 16',
#        'RequiredSkills', 'TotalSkills'],
#       dtype='object')

# %%
df['Domain'].value_counts()
# Out:
# Graphic Designer                   336
# Full Stack Developer               300
# Web Developer                      215
# App Developer                      186
# Wordpress Developer                182
#                                   ...
# IPR Attorney                         1
# SEO Specialist                       1
# Digital Marketing Expert             1
# Facebook & Instagram Ads Expert      1
# Electrical Engineer                  1
# Name: Domain, Length: 235, dtype: int64

# %%
df=df.drop('HourlyIncome', axis=1)
df=df.drop('Domain', axis=1)

# %%
df['ClassLabel'].value_counts()
# Out:
# Excellent         1799
# Good               447
# Below Average      174
# Very Good           76
# Average              5
# Name: ClassLabel, dtype: int64

# %%
df.drop_duplicates(inplace=True)

# %%
df.isnull().sum()
# Out:
# Name                    0
# Country                 0
# TotalIncome           573
# Bio                     0
#  AgencyName             4
# Rating                  0
# ClassLabel              0
# up-skill-badge        173
# up-skill-badge 2      231
# up-skill-badge 3      298
# up-skill-badge 4      424
# up-skill-badge 5      537
# up-skill-badge 6      626
# up-skill-badge 7      790
# up-skill-badge 8      923
# up-skill-badge 9     1047
# up-skill-badge 10    1187
# up-skill-badge 11    1315
# up-skill-badge 12    1430
# up-skill-badge 13    1547
# up-skill-badge 14    1698
# up-skill-badge 15    1797
# up-skill-badge 16    1849
# RequiredSkills          0
# TotalSkills             0
# dtype: int64

# %%
x = df.drop(['ClassLabel'],axis=1)

# %%
x
# Out:
#                            Name         Country  TotalIncome  \
# 0                  Rienie Du P.    South Africa          0.0
# 1                     Hassan M.        Pakistan        200.0
# 2     Venkata Samba Siva Rao A.           India         50.0
# 3                     Rameez S.        Pakistan          0.0
# 4                      Azmat Q.        Pakistan          0.0
# ...                         ...             ...          ...
# 2496            Oluwatunmise A.         Nigeria         70.0
# 2497                     Dil A.      Bangladesh          2.0
# 2498                     Cem R.  United Kingdom          NaN
# 2499            Sharmishtha  D.           India          NaN
# 2500                Narender K.           India         30.0
#
#                                                     Bio  \
# 0     Im a spontaneous hard working go getter that w...
# 1     Three years of experience in recruitment sourc...
# 2     Graphic designing skills:\n\nDesign:\n--------...
# 3     I perform my duties as an experienced bookkeep...
# 4     ✨✨✨𝐀𝐦𝐚𝐳𝐨𝐧, 𝐞𝐁𝐚𝐲, 𝐀𝐦𝐚𝐳𝐨𝐧 𝐕𝐞𝐧𝐝𝐨𝐫, 𝐖𝐚𝐥𝐦𝐚𝐫𝐭, 𝐄𝐭𝐬𝐲,...
# ...                                                 ...
# 2496  I believe that storytelling is the most powerf...
# 2497  I am an expert and experienced in Article Writ...
# 2498  Born & raised in London, UK, so I'm a natural ...
# 2499  I am an experienced E-books, web content and a...
# 2500  This was the thing I was always hoping to add ...
#
#                                AgencyName  Rating          up-skill-badge  \
# 0                      Futuristic Changes    0.00                     NaN
# 1                                Rajawork    1.00            Construction
# 2     Charam Global Solutions PVT LTD OPC    1.00                  Course
# 3     Extreme Business Solutions Pvt Ltd.    0.00        Accounts Payable
# 4                 Multan Seller Solutions    0.97                     NaN
# ...                                   ...     ...                     ...
# 2496            Exodus Digital Enterprise    0.00        Creative Writing
# 2497                       Metadiv Studio    0.00  Editing & Proofreading
# 2498                      SpectrumKod Ltd    0.00           Business Plan
# 2499                       Nayra Infotech    0.00  Indian English Dialect
# 2500                            ROI Minds    0.00            Blog Content
#
#                   up-skill-badge 2         up-skill-badge 3  \
# 0                              NaN                      NaN
# 1     Manufacturing & Construction       Energy & Utilities
# 2                            Class                   Lesson
# 3              Bank Reconciliation        Budget Management
# 4                              NaN                      NaN
# ...                            ...                      ...
# 2496        Editing & Proofreading               Screenplay
# 2497                 Fact-Checking        Technical Writing
# 2498                 Presentations                   Report
# 2499    Australian English Dialect  British English Dialect
# 2500                  Product Page               Newsletter
#
#         up-skill-badge 4  ...        up-skill-badge 9     up-skill-badge 10  \
# 0                    NaN  ...                     NaN                   NaN
# 1      Business Services  ...        Resume Screening  Interpersonal Skills
# 2        Product Support  ...                     NaN                   NaN
# 3     Payroll Accounting  ...     Accounting Software       Numeric Fluency
# 4                    NaN  ...                     NaN                   NaN
# ...                  ...  ...                     ...                   ...
# 2496               Novel  ...            Blog Content                 eBook
# 2497        Blog Content  ...                     NaN                   NaN
# 2498              Letter  ...  Editing & Proofreading                   NaN
# 2499  US English Dialect  ...                 Article             Biography
# 2500             Article  ...              Researcher                   SEO
#
#        up-skill-badge 11  up-skill-badge 12 up-skill-badge 13  \
# 0                    NaN                NaN               NaN
# 1     Candidate Sourcing                NaN               NaN
# 2                    NaN                NaN               NaN
# 3             Data Entry  Accounting Basics        Quickbooks
# 4                    NaN                NaN               NaN
# ...                  ...                ...               ...
# 2496                 NaN                NaN               NaN
# 2497                 NaN                NaN               NaN
# 2498                 NaN                NaN               NaN
# 2499                 NaN                NaN               NaN
# 2500                 NaN                NaN               NaN
#
#       up-skill-badge 14 up-skill-badge 15 up-skill-badge 16 RequiredSkills  \
# 0                   NaN               NaN               NaN             16
# 1                   NaN               NaN               NaN              5
# 2                   NaN               NaN               NaN              9
# 3     Oracle Accounting   Microsoft Excel  Customer Service              0
# 4                   NaN               NaN               NaN             16
# ...                 ...               ...               ...            ...
# 2496                NaN               NaN               NaN              6
# 2497                NaN               NaN               NaN              8
# 2498                NaN               NaN               NaN              7
# 2499                NaN               NaN               NaN              6
# 2500                NaN               NaN               NaN              6
#
#      TotalSkills
# 0              0
# 1             11
# 2              7
# 3             16
# 4              0
# ...          ...
# 2496          10
# 2497           8
# 2498           9
# 2499          10
# 2500          10
#
# [2500 rows x 24 columns]

# %%
y = df['ClassLabel']

# %%
y
# Out:
# 0       Below Average
# 1            Excellent
# 2            Excellent
# 3       Below Average
# 4            Excellent
#              ...
# 2496    Below Average
# 2497    Below Average
# 2498    Below Average
# 2499    Below Average
# 2500    Below Average
# Name: ClassLabel, Length: 2500, dtype: object

# %%
from sklearn.preprocessing import LabelEncoder

# %%
x=x.apply(LabelEncoder().fit_transform)

# %%
x
# Out:
#       Name  Country  TotalIncome   Bio   AgencyName  Rating  up-skill-badge  \
# 0     1555       69            0  1637          594       0             615
# 1      661       56           20  1961         1240      54             141
# 2     1985       33           14   433          271      54             157
# 3     1503       56            0  1431          552       0              18
# 4      297       56            0  2279         1011      51             615
# ...    ...      ...          ...   ...          ...     ...             ...
# 2496  1376       54           16  1227          543       0             158
# 2497   464        6            2  1152          981       0             196
# 2498   367       82           28   253         1419       0              99
# 2499  1750       33           28  1137         1030       0             274
# 2500  1277       33           12  1960         1231       0              79
#
#       up-skill-badge 2  up-skill-badge 3  up-skill-badge 4  ...  \
# 0                  662               692               682  ...
# 1                  358               242                98  ...
# 2                  140               371               469  ...
# 3                   73               100               436  ...
# 4                  662               692               682  ...
# ...                ...               ...               ...  ...
# 2496               216               539               405  ...
# 2497               237               597                72  ...
# 2498               443               511               331  ...
# 2499                63                97               610  ...
# 2500               451               430                53  ...
#
#       up-skill-badge 9  up-skill-badge 10  up-skill-badge 11  \
# 0                  579                536                514
# 1                  434                248                 87
# 2                  579                536                514
# 3                   12                323                131
# 4                  579                536                514
# ...                ...                ...                ...
# 2496                62                531                514
# 2497               579                536                514
# 2498               172                536                514
# 2499                40                 60                514
# 2500               432                399                514
#
#       up-skill-badge 12  up-skill-badge 13  up-skill-badge 14  \
# 0                   493                454                378
# 1                   493                454                378
# 2                   493                454                378
# 3                    11                316                217
# 4                   493                454                378
# ...                 ...                ...                ...
# 2496                493                454                378
# 2497                493                454                378
# 2498                493                454                378
# 2499                493                454                378
# 2500                493                454                378
#
#       up-skill-badge 15  up-skill-badge 16  RequiredSkills  TotalSkills
# 0                   356                355              16            0
# 1                   356                355               5           11
# 2                   356                355               9            7
# 3                   195                 90               0           16
# 4                   356                355              16            0
# ...                 ...                ...             ...          ...
# 2496                356                355               6           10
# 2497                356                355               8            8
# 2498                356                355               7            9
# 2499                356                355               6           10
# 2500                356                355               6           10
#
# [2500 rows x 24 columns]

# %% [markdown]
# Support vector machine model

# %%
#Support vector machine model
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC

# %%
xtrain,xtest,ytrain,ytest = train_test_split(x,y,test_size=25,random_state=1)

# %%
xtrain
# Out:
#       Name  Country  TotalIncome   Bio   AgencyName  Rating  up-skill-badge  \
# 852    227       83           11    82         1895      47             152
# 1282  1007       33           13  1341          477      30             224
# 680    499       33           27   578         1925      32              26
# 2364   418       83           28  1430          452      13             603
# 1495   110       56           28   612          368      42             113
# ...    ...      ...          ...   ...          ...     ...             ...
# 961    333       56           26  1542         1867      51             331
# 906   1357       33            1   507         1570      13              23
# 1097  1759       56           23  2317         1383      13             609
# 236    109       45           19  1406          533      54             539
# 1062  1140       33           20   492         1482      54             460
#
#       up-skill-badge 2  up-skill-badge 3  up-skill-badge 4  ...  \
# 852                448               226               505  ...
# 1282               474                41               676  ...
# 680                 26                31               437  ...
# 2364               269                40               273  ...
# 1495               284               343               668  ...
# ...                ...               ...               ...  ...
# 961                662               692               682  ...
# 906                268               295               263  ...
# 1097               166               392               516  ...
# 236                486               339               494  ...
# 1062               502               527               514  ...
#
#       up-skill-badge 9  up-skill-badge 10  up-skill-badge 11  \
# 852                465                348                221
# 1282               579                536                514
# 680                138                470                 28
# 2364               165                338                156
# 1495               579                536                514
# ...                ...                ...                ...
# 961                579                536                514
# 906                 15                175                201
# 1097                93                287                395
# 236                579                536                514
# 1062               499                123                387
#
#       up-skill-badge 12  up-skill-badge 13  up-skill-badge 14  \
# 852                 154                222                287
# 1282                493                454                378
# 680                  27                454                378
# 2364                157                  7                 18
# 1495                493                454                378
# ...                 ...                ...                ...
# 961                 493                454                378
# 906                  13                350                363
# 1097                 85                 35                223
# 236                 493                454                378
# 1062                105                158                 56
#
#       up-skill-badge 15  up-skill-badge 16  RequiredSkills  TotalSkills
# 852                 340                145               0           16
# 1282                356                355              11            5
# 680                 356                355               4           12
# 2364                161                179               0           16
# 1495                356                355               8            8
# ...                 ...                ...             ...          ...
# 961                 356                355              15            1
# 906                  10                  8               0           16
# 1097                 72                355               1           15
# 236                 356                355               8            8
# 1062                239                 34               0           16
#
# [2475 rows x 24 columns]

# %%
sv = SVC()

# %%
sv.fit(xtrain,ytrain)
# Out:
# SVC()

# %%
sv.score(xtest,ytest)
# Out:
# 0.84

# %%
#KNeighborsClassifier
from sklearn.neighbors import KNeighborsClassifier
knc=KNeighborsClassifier(n_neighbors=9)

# %%
knc.fit(xtrain,ytrain)
# Out:
# KNeighborsClassifier(n_neighbors=9)

# %%
KNeighborsClassifier(n_neighbors=9)
# Out:
# KNeighborsClassifier(n_neighbors=9)

# %%
knc.score(xtest,ytest)
# Out:
# 0.8

# %%
#Random Forest Classifier
from sklearn.ensemble import RandomForestClassifier

# %%
clf=RandomForestClassifier

# %%
#Randomly choose n_estimator
clf=RandomForestClassifier(n_estimators=80,oob_score=True,n_jobs=-1,random_state=200)

# %%
clf.fit(xtrain,ytrain)
# Out:
# RandomForestClassifier(n_estimators=80, n_jobs=-1, oob_score=True,
#                        random_state=200)

# %%
clf.score(xtest,ytest)
# Out:
# 0.96

# %%
#accuracy on new data set
clf.oob_score_
# Out:
# 0.9838383838383838

# %%
# !pip3 install xgboost
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: xgboost in /usr/local/lib/python3.8/dist-packages (0.90)
# Requirement already satisfied: scipy in /usr/local/lib/python3.8/dist-packages (from xgboost) (1.7.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from xgboost) (1.21.6)

# %%
from xgboost import XGBClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.datasets import load_wine

# %%
xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size=0.3, random_state=1)

# %%
# fit model no training data
xg = XGBClassifier()

# %%
X, y = load_wine(return_X_y=True, as_frame=True)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1)

# %%
model = XGBClassifier(use_label_encoder=False, eval_metric='mlogloss')

# %%
model.fit(X_train, y_train)
# Out:
# XGBClassifier(eval_metric='mlogloss', objective='multi:softprob',
#               use_label_encoder=False)

# %%
y_pred = model.predict(X_test)

# %%
y_pred
# Out:
# array([2, 1, 0, 1, 0, 2, 1, 0, 2, 1, 0, 0, 1, 0, 1, 1, 2, 0, 1, 0, 0, 1,
#        2, 0, 0, 2, 0, 0, 0, 2, 1, 2, 2, 0, 1, 1, 1, 0, 1, 0, 0, 1, 2, 0,
#        0, 0, 1, 0, 0, 0, 1, 2, 2, 0])

# %%
accuracy = accuracy_score(y_test, y_pred)
accuracy
# Out:
# 0.9629629629629629
